# %% [markdown]
# ### Flask Web App Development

# %% [markdown]
# Q1. State the key terms when developing a web application using flask and explain its respective purposes. Include any additional terms or softwares that can be incoporated into the web app and its purpose.

# %% [markdown]
# Q2. John is a H2 A level computing student and wants to know more about the process of how requests are sent from his computer using HTTP to servers and how he is able to login and get different pages when he requests it. Outline to john, with the aid of a diagram, how when John requests for the login page of his email the requests are sent to the server and the response is received by the client, John.

# %% [markdown]
# Q3. What is a key difference between a POST request and a GET request?

# %% [markdown]
# Q4. Emily is an aspiring web app developer. She recently came across the developer tools on her chrome browser and under the Networks tab realised that once she refreshed a page, a bunch a 'stuff' popped up as depicted in the diagram. Explain to Emily what the 'stuff' is the order of how the 'stuff' is sent over and the procedure of viewing what each thing is.
# ![Screenshot%202024-02-25%20at%205.07.52%20PM.png](attachment:Screenshot%202024-02-25%20at%205.07.52%20PM.png)

# %% [markdown]
# Q5. Timothy is currently learning HTML and has created a simple web page shown below talking about his introduction to computing and his future plans. Task 1: In the paragraph tag Timothy wants to split up the three sentences into 3 seperate lines how does he do so?

# %%
<! DOCTYPE html>
<html>
<head>
    <title>My computing journey</title>
</head>
<body>
    <h1> Welcome to my Webpage
    <h2> Who am I?
    <p> Hello I am Timothy and I am an aspiring software developer. My fields of interests are cybersecurity and software developer. I am also a H2 A level computing student.
</body>
</html>

# %% [markdown]
# Task 2: Now, Timothy finds that his sentences are very close to each other. How does he rewrite his code such that there is spacing between each line?

# %%
# Write your code here

# %% [markdown]
# Q6. You run a software development company focusing on the development websites for others. Paul, your client, has given you a task of developing a website. Below is the list of things he requests you to have in the website.
# 1. Title of the website: School of Business
# 2. A header (black in colour): Welcome to ABC School of Business
# 3. A smaller header (red in colour): Our partners:
# 4. 3 links which route you to 3 different websites one being https://www.hbs.edu/, the other, https://www.stanford.edu/ and lastly, https://www.sc.com/sg/
# 5. Below each link should be a short description of what each partner does.
#
# For styling purposes you are recommended to use embedded CSS and showcase overriding by using inline CSS.

# %%
# Write your code here

# %% [markdown]
# Q7. For styling of web pages using CSS, there are three techniques to employ. State the techniques and give a brief description of how it is employed. Additionally state why a method is chosen over another.
